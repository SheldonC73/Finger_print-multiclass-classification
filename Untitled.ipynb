# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img

# %%
train_path = 'training data'
test_path = 'testing data'
train_data = []
train_labels = []
test_data = []
test_labels = []
for folder in os.listdir(train_path):
    sub_folder_path = os.path.join(train_path, folder)
    if os.path.isdir(sub_folder_path):
        for file in os.listdir(sub_folder_path):
            file_path = os.path.join(sub_folder_path, file)
            if os.path.isfile(file_path):
                img = load_img(file_path, color_mode='rgb', target_size=(150, 150))
                train_data.append(img_to_array(img)/255.0)
                train_labels.append(int(folder)-1)

for folder in os.listdir(test_path):
    sub_folder_path = os.path.join(test_path, folder)
    if os.path.isdir(sub_folder_path):
        for file in os.listdir(sub_folder_path):
            file_path = os.path.join(sub_folder_path, file)
            if os.path.isfile(file_path):
                img = load_img(file_path, color_mode='rgb', target_size=(150, 150))
                test_data.append(img_to_array(img)/255.0)
                test_labels.append(int(folder)-1)

# %%
plt.figure(figsize=(8,8))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(train_data[i])
    plt.xlabel(train_labels[i])
plt.show()

# %%
input_shape = (150,150, 3)
kernel_size = 3
pool_size = 2
filters = 64
dropout = 0.5
num_labels = 2

 
model.add(MaxPooling2D(pool_size))
model.add(Conv2D(filters=128,
                  kernel_size=kernel_size,
                  activation='relu')
                  )
model.add(MaxPooling2D(pool_size))
model.add(Conv2D(filters=256,
                  kernel_size=kernel_size,
                  activation='relu')
                  )
model.add(MaxPooling2D(pool_size))
model.add(Dropout(dropout))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(69 , activation='softmax'))

model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_25 (Conv2D)                   │ (None, 148, 148, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_25 (MaxPooling2D)      │ (None, 74, 74, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_26 (Conv2D)                   │ (None, 72, 72, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_26 (MaxPooling2D)      │ (None, 36, 36, 32)          │               0 │
# ...

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy,
              metrics=['accuracy'])

callback = EarlyStopping(monitor='val_loss',
                                  mode="min", 
                                  patience=3,
                                  restore_best_weights=True)

ft = model.fit(np.array(train_data), np.array(train_labels), epochs = 20, verbose = 1, 
               validation_data = (np.array(test_data), np.array(test_labels)), callbacks = [callback])
# Out:
# Epoch 1/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.1571 - loss: 3.1133 - val_accuracy: 0.0833 - val_loss: 3.4264
# Epoch 2/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1918 - loss: 3.0134 - val_accuracy: 0.1000 - val_loss: 3.3964
# Epoch 3/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.1938 - loss: 2.9093 - val_accuracy: 0.1167 - val_loss: 3.3980
# Epoch 4/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.2061 - loss: 2.7126 - val_accuracy: 0.1000 - val_loss: 3.5022
# Epoch 5/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.2274 - loss: 2.6499 - val_accuracy: 0.0667 - val_loss: 3.4866

# %%
plt.plot(ft.history['accuracy'],label='accuracy')
plt.plot(ft.history['val_accuracy'],label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
test_loss, test_acc = model.evaluate(np.array(test_data),
                                     np.array(test_labels),
                                     verbose=2)

print('Test Accuracy is',test_acc)
# Out:
# 2/2 - 0s - 55ms/step - accuracy: 0.1000 - loss: 3.3964
# Test Accuracy is 0.10000000149011612

# %%
path = "loki.jpg"
img = load_img(path , color_mode = 'rgb' , target_size = (150,150))
final_img = img_to_array(img)
final_img /= 255.0
val = model.predict(np.array([final_img]))
print(np.argmax(val))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 68
